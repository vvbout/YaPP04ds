# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-проверка-данных" data-toc-modified-id="Загрузка-и-проверка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка и проверка данных</a></span></li><li><span><a href="#Проверка-дубликатов" data-toc-modified-id="Проверка-дубликатов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка дубликатов</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-объектов-с-нулевым-значением-расчета-эффективности" data-toc-modified-id="Анализ-объектов-с-нулевым-значением-расчета-эффективности-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ объектов с нулевым значением расчета эффективности</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-расчета-эффективности-обогащения-на-обучающей-выборке" data-toc-modified-id="Проверка-расчета-эффективности-обогащения-на-обучающей-выборке-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка расчета эффективности обогащения на обучающей выборке</a></span><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Анализ-признаков,-исключенных-из-тестовой-выборки" data-toc-modified-id="Анализ-признаков,-исключенных-из-тестовой-выборки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ признаков, исключенных из тестовой выборки</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Анализ-изменения-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Анализ-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Анализ распределения размеров гранул сырья на обучающей и тестовой выборках</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Анализ-суммарной-концентрации-всех-веществ-в-сырье,-черновом-и-финальном-концентратах" data-toc-modified-id="Анализ-суммарной-концентрации-всех-веществ-в-сырье,-черновом-и-финальном-концентратах-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Анализ суммарной концентрации всех веществ в сырье, черновом и финальном концентратах</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-распределения-дат-в-обучающей-и-тестовой-выборках" data-toc-modified-id="Проверка-распределения-дат-в-обучающей-и-тестовой-выборках-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Проверка распределения дат в обучающей и тестовой выборках</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Формирование-признаков-и-целевой-перменной,-стандартизация" data-toc-modified-id="Формирование-признаков-и-целевой-перменной,-стандартизация-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Формирование признаков и целевой перменной, стандартизация</a></span></li><li><span><a href="#Вывбор-лучшей-модели,-кросс-валидация" data-toc-modified-id="Вывбор-лучшей-модели,-кросс-валидация-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Вывбор лучшей модели, кросс-валидация</a></span><ul class="toc-item"><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#Lasso" data-toc-modified-id="Lasso-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Lasso</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-лучшей-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-лучшей-модели-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка лучшей модели на тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# **Задача проекта:**
#
# На основе сырых данных с параметрами добычи и очистки золотоносной руды, представленных в файлах:
#
# 1. gold_recovery_train_new.csv — обучающая выборка
# 2. gold_recovery_test_new.csv — тестовая выборка
# 3. gold_recovery_full_new.csv — исходные данные
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
#
# **Описание данных:**
# 1. Технологический процесс
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# * Xanthate — ксантогенат (промотер, или активатор флотации)
# * Sulphate — сульфат (на данном производстве сульфид натрия)
# * Depressant — депрессант (силикат натрия).
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
# 2. Параметры этапов:
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
# 3. Наименование признаков:
# Наименование признаков должно быть такое:
# [этап].[тип_параметра].[название_параметра]
#
# **Возможные значения для блока [этап]:**
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики
#
# > Подготовить прототип модели машинного обучения для компании, разрабатывающей решения для эффективной работы промышленных предприятий.
# >
# > Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
# >
# > Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
# >

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка и проверка данных

# %%
# загружем библиотеки и подготавливаем рабочее пространство

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import pandas as pd
import numpy as np

from numpy.random import RandomState
RANDOM_STATE = RandomState(0)

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import make_scorer
from sklearn.inspection import permutation_importance

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# загружаем файлы
data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv')
data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv')
data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
# читаем первые 2 строки
display(data_train.head(2))
display(data_test.head(2))
display(data_full.head(2))
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
#
#    final.output.tail_pb  final.output.tail_sol  final.output.tail_au  \
# 0              0.895447              16.904297              2.143149
# 1              0.927452              16.634514              2.224930
#
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     127.092003                         10.128295
# ...

# %%
# выводим общую информацию о файлах
data_full.info()
print()
data_train.info()
print()
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# **Выводы по данным:**
# * исходный файл содержит  19 439 записей и 87
# * обучающая выборка содержит 14 149 записей и 87 колонок
# * тестовая выборка содержит 5 290 записей и 53 колонки
# * обучающая и тестовая выборки поделены в пропорции 73 х 27
# * все параметры записаны в ожидаемом формате float64, кроме параметра date
# * преобразуем тип данных параметра date из object в datetime

# %%
# преобразуем тип данных параметра date из object в datetime
for data in [data_full, data_train, data_test]:
           for column in data:
            if 'date' in column:
                data[column]=pd.to_datetime(data[column])
                display(data['date'].dtypes)
# Out:
# dtype('<M8[ns]')
# dtype('<M8[ns]')
# dtype('<M8[ns]')

# %% [markdown]
# ### Проверка дубликатов

# %%
# проверяем наличие дубликатов
print('Количество полных дубликатов в исходном файле:\n', data_full.duplicated().sum())
# Out:
# Количество полных дубликатов в исходном файле:
#  0

# %% [markdown]
# ### Обработка пропущенных значений

# %%
# проверяем пропущенные значения в иcходном файле
data_full_null = data_full.isna().sum().sort_values(ascending=False).to_frame(name='null_qnt')
data_full_null['null_share'] = data_full_null['null_qnt'] / len(data_full) *100
data_full_null = data_full_null.reset_index().rename(columns={"index":'parameter'})
data_full_null = data_full_null[data_full_null['null_qnt'] != 0]
display(data_full_null)
# Out:
#                                             parameter  null_qnt  null_share
# 0                   secondary_cleaner.output.tail_sol      1748    8.992232
# 1                  rougher.input.floatbank11_xanthate       453    2.330367
# 2                     rougher.state.floatbank10_e_air       436    2.242914
# 3              primary_cleaner.output.concentrate_sol       370    1.903390
# 4            secondary_cleaner.state.floatbank2_a_air       220    1.131745
# 5                        final.output.concentrate_sol       211    1.085447
# 6                             rougher.input.feed_size       145    0.745923
# 7               primary_cleaner.output.concentrate_pb       116    0.596739
# 8                      primary_cleaner.input.xanthate       104    0.535007
# 9                                final.output.tail_pb       101    0.519574
# 10                              rougher.input.feed_pb       100    0.514430
# ...

# %%
# провереям распределение данных по признаку с максимальным количеством пропущенных значений (9%)
data_full['secondary_cleaner.output.tail_sol']\
.plot(kind = 'hist', \
      bins=100, title='Распределение данных по признаку secondary_cleaner.output.tail_sol');

# %%
# выводим стат информацию по параметру
data_full['secondary_cleaner.output.tail_sol'].describe()
# Out:
# count    17691.000000
# mean         7.167247
# std          3.916079
# min          0.000000
# 25%          3.845475
# 50%          7.685827
# 75%         10.411296
# max         26.000772
# Name: secondary_cleaner.output.tail_sol, dtype: float64

# %% [markdown]
# **Выводы по данным и графику:**
# * данные емеют не нормальное полимодальное распределение
# * минимальное значение равно 0
# * максимальное значение равно 26
# * среднее и медиана близки: 7.17 и 7.69
# * 75% данных находятся в диапазоне от 0 до 10.41

# %%
# выводим все параметры, относящиеся к этапу вторичной очистки
data_full_secondary_cleaner = data_full.filter(regex = 'secondary_cleaner')
display(data_full_secondary_cleaner.shape)
# Out:
# (19439, 22)

# %%
# строим тепловую карту корреляции к этапу вторичной очистки
plt.figure(figsize=(14, 5)) 
heatmap = sns.heatmap(data_full_secondary_cleaner.corr()\
                      , annot=True, fmt='.2f', linewidths=.5, cmap="YlGnBu") 
heatmap.set_title('Тепловая карта корреляции, этап вторичной очистки', fontsize=12);

# %% [markdown]
# **Выводы по графику:**
# * сильной линейной зависимости между параметром tail_sol и остальными параметрами, характеризующими этап вторичной очистки не выявлено

# %%
# проверяем пропущенные значения в обучающей выборке
data_train_null = data_train.isna().sum().sort_values(ascending=False).to_frame(name='null_qnt')
data_train_null['null_share'] = data_train_null['null_qnt'] / len(data_train) *100
data_train_null = data_train_null.reset_index().rename(columns={"index":'parameter'})
data_train_null = data_train_null[data_train_null['null_qnt'] != 0]
display(data_train_null)
# Out:
#                                             parameter  null_qnt  null_share
# 0                   secondary_cleaner.output.tail_sol      1605   11.343558
# 1                     rougher.state.floatbank10_e_air       436    3.081490
# 2                  rougher.input.floatbank11_xanthate       428    3.024949
# 3              primary_cleaner.output.concentrate_sol       286    2.021344
# 4            secondary_cleaner.state.floatbank2_a_air       217    1.533677
# 5                        final.output.concentrate_sol       211    1.491271
# 6                             rougher.input.feed_size       144    1.017740
# 7                      primary_cleaner.input.xanthate       100    0.706764
# 8                               rougher.input.feed_pb       100    0.706764
# 9                                final.output.tail_pb       100    0.706764
# 10              primary_cleaner.output.concentrate_pb        86    0.607817
# ...

# %%
# проверяем пропущенные значения в тестовой выборке
data_test_null = data_test.isna().sum().sort_values(ascending=False).to_frame(name='null_qnt')
data_test_null['null_share'] = data_test_null['null_qnt'] / len(data_test) *100
data_test_null = data_test_null.reset_index().rename(columns={"index":'parameter'})
data_test_null = data_test_null[data_test_null['null_qnt'] != 0]
display(data_test_null)
# Out:
#                                    parameter  null_qnt  null_share
# 0         rougher.input.floatbank11_xanthate        25    0.472590
# 1                     rougher.input.feed_sol        21    0.396975
# 2   secondary_cleaner.state.floatbank3_a_air         9    0.170132
# 3          rougher.input.floatbank11_sulfate         8    0.151229
# 4           primary_cleaner.input.depressant         5    0.094518
# 5          rougher.input.floatbank10_sulfate         5    0.094518
# 6             primary_cleaner.input.xanthate         4    0.075614
# 7              primary_cleaner.input.sulfate         4    0.075614
# 8                    rougher.input.feed_rate         3    0.056711
# 9   secondary_cleaner.state.floatbank2_a_air         3    0.056711
# 10  secondary_cleaner.state.floatbank2_b_air         2    0.037807
# 11                   rougher.input.feed_size         1    0.018904

# %% [markdown]
# #### Выводы
# * из 87 параметров исходного файла 63 содержат пропущенные значения
# * самая высокая доля пропущенных значений приходится на параметр secondary_cleaner.output.tail_sol = 8,99%
# * 5 параметров находятся в диапазоне от 1 до 2,33%
# * 58 параметров имеют пропущенные значения менее 1%
# * анализ параметра secondary_cleaner.output.tail_sol с самой высокой долей пропусков не выявил сильной линейной зависимости данного параметра с другими, относящимися к этапу вторичной очистки
# * по условиям проекта данные индексируются датой и временем получения информации (параметр date); Соседние по времени параметры часто похожи.
# * принято решение произвести замену пропущенных значений последним действительным значением вперед

# %%
# производим замену пропущенных значений
data_full = data_full.fillna(method='ffill')
data_train= data_train.fillna(method='ffill') 
data_test = data_test.fillna(method='ffill')

print('Количество пропущенных значений после замены в исходном файле:', data_full.isna().sum())
print()
print('Количество пропущенных значений после замены в обучающей выборке:', data_train.isna().sum())
print()
print('Количество пропущенных значений после замены в тестовой выборке:', data_test.isna().sum())
# Out:
# Количество пропущенных значений после замены в исходном файле: date                                                  0
# final.output.concentrate_ag                           0
# final.output.concentrate_pb                           0
# final.output.concentrate_sol                          0
# final.output.concentrate_au                           0
# final.output.recovery                                 0
# final.output.tail_ag                                  0
# final.output.tail_pb                                  0
# final.output.tail_sol                                 0
# final.output.tail_au                                  0
# primary_cleaner.input.sulfate                         0
# primary_cleaner.input.depressant                      0
# primary_cleaner.input.feed_size                       0
# primary_cleaner.input.xanthate                        0
# primary_cleaner.output.concentrate_ag                 0
# primary_cleaner.output.concentrate_pb                 0
# ...

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ объектов с нулевым значением расчета эффективности

# %%
# строим диагарммы размаха по целевомым переменным всей выборки
fig, axes = plt.subplots(nrows=1, ncols=2)
fig.set_figheight(5)
fig.set_figwidth(15)
fig.suptitle('Диаграммы размаха целевых переменных', y=0.95, size=16)

data_full.boxplot(column='rougher.output.recovery', ax=axes[0], grid = True)
data_full.boxplot(column='final.output.recovery', ax=axes[1], grid = True);

# %%
# создаем переменную для объектов целевой переменной rougher.output.recovery с значением 0
r_recovery_null = data_full[data_full['rougher.output.recovery'] == 0]
display(r_recovery_null.shape)
display(r_recovery_null.sample(5))
# Out:
# (394, 87)
#                      date  final.output.concentrate_ag  \
# 15528 2018-02-07 23:59:59                     6.920489
# 10424 2017-06-06 10:59:59                     4.436278
# 10398 2017-06-05 08:59:59                     4.784883
# 10452 2017-06-07 14:59:59                     4.699609
# 15620 2018-02-11 23:59:59                     4.909904
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 15528                    10.113684                     10.410341
# 10424                    10.611818                      8.395022
# 10398                    10.932726                      8.369214
# 10452                    10.135881                      7.007272
# 15620                     9.941006                      8.191698
#
#        final.output.concentrate_au  final.output.recovery  \
# 15528                    44.359659              74.512525
# 10424                    45.633092              55.272374
# ...

# %%
# проверяем параметры равные 0
r_recovery_null = r_recovery_null.drop('date', axis=1)
for column in r_recovery_null:
    if r_recovery_null[column].sum() == 0:
        print('null_is:',[column])
# Out:
# null_is: ['rougher.output.concentrate_ag']
# null_is: ['rougher.output.concentrate_pb']
# null_is: ['rougher.output.concentrate_sol']
# null_is: ['rougher.output.concentrate_au']
# null_is: ['rougher.output.recovery']

# %%
# создаем переменную для объектов целевой переменной final.output.recovery с значением 0
f_recovery_null = data_full[data_full['final.output.recovery'] == 0]
display(f_recovery_null.shape)
display(f_recovery_null.sample(5))
# Out:
# (98, 87)
#                      date  final.output.concentrate_ag  \
# 14736 2017-12-17 02:59:59                          0.0
# 8636  2017-03-06 17:59:59                          0.0
# 11540 2017-07-26 04:59:59                          0.0
# 13697 2017-11-01 11:59:59                          0.0
# 13364 2017-10-17 22:59:59                          0.0
#
#        final.output.concentrate_pb  final.output.concentrate_sol  \
# 14736                          0.0                           0.0
# 8636                           0.0                           0.0
# 11540                          0.0                           0.0
# 13697                          0.0                           0.0
# 13364                          0.0                           0.0
#
#        final.output.concentrate_au  final.output.recovery  \
# 14736                          0.0                    0.0
# 8636                           0.0                    0.0
# ...

# %%
# проверяем параметры равные 0
f_recovery_null = f_recovery_null.drop('date', axis=1)
for column in f_recovery_null:
    if f_recovery_null[column].sum() == 0:
        print('null_is:',[column])
# Out:
# null_is: ['final.output.concentrate_ag']
# null_is: ['final.output.concentrate_pb']
# null_is: ['final.output.concentrate_sol']
# null_is: ['final.output.concentrate_au']
# null_is: ['final.output.recovery']

# %% [markdown]
# #### Выводы
# * анализ нулевых значений целевой переменной показал очевидное наличие ошибки внесения данных, влияющей на целевую переменную
# * **rougher.output.recovery** - 394 объекта равны нулю, т.к. пропущены значения слогаемых параметров:
# >
# > null_is: ['rougher.output.concentrate_ag']
# >
# > null_is: ['rougher.output.concentrate_pb']
# >
# > null_is: ['rougher.output.concentrate_sol']
# >
# >null_is: ['rougher.output.concentrate_au']
# >
# >null_is: ['rougher.output.recovery']
# >
#
# все остальные параметры содержат ожидаемые значения
# * **final.output.recovery** - 98 объектов равны нулю, т.к. пропущены значения слогамых параметров:
# >
# > null_is: ['final.output.concentrate_ag']
# >
# > null_is: ['final.output.concentrate_pb']
# >
# > null_is: ['final.output.concentrate_sol']
# >
# >null_is: ['final.output.concentrate_au']
# >
# >null_is: ['final.output.recovery']
# >
#
# все остальные параметры содержат ожидаемые значения
# * приянто решение удалить объекты из выборок

# %%
# отфильтровываем объекты с нулевыми значениями переменных из выборок
data_full = data_full[data_full['rougher.output.recovery'] > 0]
data_full = data_full[data_full['final.output.recovery'] > 0]

data_train = data_train[data_train['rougher.output.recovery'] > 0]
data_train = data_train[data_train['final.output.recovery'] > 0]

display(data_full.shape)
display(data_train.shape)
# Out:
# (18949, 87)
# (13795, 87)

# %% [markdown]
# ### Проверка расчета эффективности обогащения на обучающей выборке

# %%
# выводим стат данные этапа флотации по признаку rougher.output.recovery для обучающей выборки
data_train['rougher.output.recovery'].describe()
# Out:
# count    13795.000000
# mean        84.505005
# std          7.984405
# min          2.520854
# 25%         80.374115
# 50%         85.518252
# 75%         90.289513
# max        100.000000
# Name: rougher.output.recovery, dtype: float64

# %%
# добавляем проверку расчета эффективности для этапа флотации в обучающую выборку
data_train_copy = data_train.copy()
data_train_copy['rec_check'] = (data_train_copy['rougher.output.concentrate_au']\
                           * (data_train_copy['rougher.input.feed_au'] - data_train_copy['rougher.output.tail_au']))\
                           / (data_train_copy['rougher.input.feed_au']\
                           * (data_train_copy['rougher.output.concentrate_au'] - data_train_copy['rougher.output.tail_au']))\
                           * 100
display(data_train_copy['rec_check'].describe())
# Out:
# count    13795.000000
# mean        84.505005
# std          7.984405
# min          2.520854
# 25%         80.374115
# 50%         85.518252
# 75%         90.289513
# max        100.000000
# Name: rec_check, dtype: float64

# %%
# строим гистограмму распределения данных проверочного расчета обогащения для обучающей выборки
plt.figure(figsize=(15, 5))
data_train_copy['rougher.output.recovery'].plot(kind = 'hist', color = 'blue', alpha = 0.5, label = 'data_train_rec', bins = 100)
data_train_copy['rec_check'].plot(kind = 'hist', color='orange', alpha = 0.5, label = 'data_train_rec_check', bins = 100)
plt.title('Распределение данных обогащения оригинал / проверка')
plt.legend()
plt.show()

# %%
# рассчитываем MAE
MAE = abs(data_train_copy['rec_check'] - data_train_copy['rougher.output.recovery'])\
/ len(data_train_copy['rougher.output.recovery'])
print('MAE обогащения этапа флотации на обучающей выборке (оригинал vs расчет):', MAE.mean())
# Out:
# MAE обогащения этапа флотации на обучающей выборке (оригинал vs расчет): 7.206723425183508e-19

# %% [markdown]
# #### Выводы:
# * расчет эффективности обогащения по этапу флотации на обучающей выборке показал, что средняя абсолютная ошибка стремиться к нулю, рассчетные данные совпали с оригинальными
# * на примере этапа флотации можно считать, что эффективность обогащения рассчитана правильно

# %% [markdown]
# ### Анализ признаков, исключенных из тестовой выборки

# %%
# выводим признаки, исключенные из тестовой выборки
data_train_col = data_train.columns
data_test_col = data_test.columns
excl_param = pd.Series(list(set(data_train_col) - set(data_test_col)))
display(excl_param.sort_values())
excl_param_list = excl_param.to_list
# Out:
# 22                          final.output.concentrate_ag
# 10                          final.output.concentrate_au
# 26                          final.output.concentrate_pb
# 33                         final.output.concentrate_sol
# 8                                 final.output.recovery
# 27                                 final.output.tail_ag
# 9                                  final.output.tail_au
# 3                                  final.output.tail_pb
# 5                                 final.output.tail_sol
# 12                primary_cleaner.output.concentrate_ag
# 15                primary_cleaner.output.concentrate_au
# 19                primary_cleaner.output.concentrate_pb
# 0                primary_cleaner.output.concentrate_sol
# 24                       primary_cleaner.output.tail_ag
# 7                        primary_cleaner.output.tail_au
# 14                       primary_cleaner.output.tail_pb
# 11                      primary_cleaner.output.tail_sol
# ...

# %% [markdown]
# #### Выводы
# * параметры, исключенные из тестовой выборки представляют собой выходные признаки после каждого технологического этапа или расчетные на их основе
# * каждый из этих параметров может быть целевым и являться предметом предсказания
# * присутствие признаков вызвало бы мультиколлинеарность и ослабило предсаказательную силу модели
# * целевые параметры в рамках проекта (final.output.recovery и rougher.output.recovery) также исключены из тестовой выборки
# * для моделей прогнозирования целевые признаки для тестовой выборки потребуют восстановления

# %% [markdown]
# ### Анализ изменения концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
# выводим список параметров, определяющих концентрацию металлов на разных этапах очистки
data_full_concentrate = data_full.filter(regex = 'concentrate')
data_full_concentrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18949 entries, 0 to 19438
# Data columns (total 13 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   final.output.concentrate_ag                    18949 non-null  float64
#  1   final.output.concentrate_pb                    18949 non-null  float64
#  2   final.output.concentrate_sol                   18949 non-null  float64
#  3   final.output.concentrate_au                    18949 non-null  float64
#  4   primary_cleaner.output.concentrate_ag          18949 non-null  float64
#  5   primary_cleaner.output.concentrate_pb          18949 non-null  float64
#  6   primary_cleaner.output.concentrate_sol         18949 non-null  float64
#  7   primary_cleaner.output.concentrate_au          18949 non-null  float64
#  8   rougher.calculation.sulfate_to_au_concentrate  18949 non-null  float64
# ...

# %%
# строим гистограммы распределения данных
fig, ax = plt.subplots(3, 1, sharex='all')
fig.set_figheight(7)
fig.set_figwidth(15)
fig.suptitle('Концентрация металлов на разных этапах очистки', y=0.95, size=16)

ax[0].hist(data_full[data_full['rougher.output.concentrate_ag']>0.01]['rougher.output.concentrate_ag']\
, bins=50, alpha = 0.5, label = 'rougher.output.concentrate_ag')
ax[0].hist(data_full[data_full['rougher.output.concentrate_ag']>0.01]['rougher.output.concentrate_pb']\
, bins=50, alpha = 0.5, label = 'rougher.output.concentrate_pb')
ax[0].hist(data_full[data_full['rougher.output.concentrate_ag']>0.01]['rougher.output.concentrate_au']\
, bins=50, alpha = 0.5, label = 'rougher.output.concentrate_au')
ax[0].legend()
ax[0].set_title('Концентрация металлов после флотации')
ax[0].grid()

ax[1].hist(data_full[data_full['primary_cleaner.output.concentrate_ag']>0.01]['primary_cleaner.output.concentrate_ag']\
, bins=50, alpha = 0.5, label = 'primary_cleaner.output.concentrate_ag')
ax[1].hist(data_full[data_full['primary_cleaner.output.concentrate_pb']>0.01]['primary_cleaner.output.concentrate_pb']\
, bins=50, alpha = 0.5, label = 'primary_cleaner.output.concentrate_pb')
ax[1].hist(data_full[data_full['primary_cleaner.output.concentrate_au']>0.01]['primary_cleaner.output.concentrate_au']\
, bins=50, alpha = 0.5, label = 'primary_cleaner.output.concentrate_au')
ax[1].legend()
ax[1].set_title('Концентрация металлов после первого этапа очистки')
ax[1].grid()

ax[2].hist(data_full[data_full['final.output.concentrate_ag']>0.01]['final.output.concentrate_ag']\
, bins=50, alpha = 0.5, label = 'final.output.concentrate_ag')
ax[2].hist(data_full[data_full['final.output.concentrate_pb']>0.01]['final.output.concentrate_pb']\
, bins=50, alpha = 0.5, label = 'final.output.concentrate_pb')
ax[2].hist(data_full[data_full['final.output.concentrate_au']>0.01]['final.output.concentrate_au']\
, bins=50, alpha = 0.5, label = 'final.output.concentrate_au')
ax[2].legend()
ax[2].set_title('Концентрация металлов в финальном концентрате')
ax[2].grid()

plt.show()

# %%
# выводим стат данные по серебру
rougher_output_concentrate_ag = data_full['rougher.output.concentrate_ag'].describe().to_frame()
primary_cleaner_output_concentrate_ag = data_full['primary_cleaner.output.concentrate_ag'].describe().to_frame()
final_output_concentrate_ag = data_full['final.output.concentrate_ag'].describe().to_frame()

ag = rougher_output_concentrate_ag.join(primary_cleaner_output_concentrate_ag, how='left')\
.join(final_output_concentrate_ag, how='left')
display(ag)
# Out:
#        rougher.output.concentrate_ag  primary_cleaner.output.concentrate_ag  \
# count                   18949.000000                           18949.000000
# mean                       12.243959                               8.459371
# std                         2.136637                               2.045988
# min                         0.010000                               0.000000
# 25%                        10.711273                               7.278120
# 50%                        12.169414                               8.524305
# 75%                        13.766656                               9.820708
# max                        24.480271                              16.081632
#
#        final.output.concentrate_ag
# count                 18949.000000
# mean                      5.200005
# std                       1.326763
# min                       0.010000
# 25%                       4.271234
# 50%                       5.081195
# ...

# %%
# выводим стат данные по свинцу
rougher_output_concentrate_pb = data_full['rougher.output.concentrate_pb'].describe().to_frame()
primary_cleaner_output_concentrate_pb = data_full['primary_cleaner.output.concentrate_pb'].describe().to_frame()
final_output_concentrate_pb = data_full['final.output.concentrate_pb'].describe().to_frame()

pb = rougher_output_concentrate_pb.join(primary_cleaner_output_concentrate_pb, how='left')\
.join(final_output_concentrate_pb, how='left')
display(pb)
# Out:
#        rougher.output.concentrate_pb  primary_cleaner.output.concentrate_pb  \
# count                   18949.000000                           18949.000000
# mean                        7.763225                               9.805949
# std                         1.438036                               2.569553
# min                         0.010000                               0.000000
# 25%                         6.800148                               8.663774
# 50%                         7.773034                              10.133624
# 75%                         8.584371                              11.405363
# max                        13.617072                              17.081278
#
#        final.output.concentrate_pb
# count                 18949.000000
# mean                     10.034090
# std                       1.514914
# min                       0.010000
# 25%                       9.151292
# 50%                      10.113495
# ...

# %%
# выводим стат данные по золоту
rougher_output_concentrate_au = data_full['rougher.output.concentrate_au'].describe().to_frame()
primary_cleaner_output_concentrate_au = data_full['primary_cleaner.output.concentrate_au'].describe().to_frame()
final_output_concentrate_au = data_full['final.output.concentrate_au'].describe().to_frame()

au = rougher_output_concentrate_au.join(primary_cleaner_output_concentrate_au, how='left')\
.join(final_output_concentrate_au, how='left')
display(au)
# Out:
#        rougher.output.concentrate_au  primary_cleaner.output.concentrate_au  \
# count                   18949.000000                           18949.000000
# mean                       20.177817                              32.101133
# std                         2.467617                               5.577711
# min                         0.010000                               0.000000
# 25%                        18.919702                              30.447899
# 50%                        20.325517                              32.797721
# 75%                        21.751757                              35.005221
# max                        28.824507                              45.933934
#
#        final.output.concentrate_au
# count                 18949.000000
# mean                     44.280284
# std                       4.042040
# min                       0.010000
# 25%                      43.415190
# 50%                      45.007208
# ...

# %% [markdown]
# #### Выводы
# * в ходе технологического процесса обработки золотоносной руды металлы серебра, свинца и золота ведут себя по разному
# * концентрация **серебра** в процессе обработки **снижается**:
# >
# > среднее значение падает с 12.24 до 5.17
# >
# > максимальное значение падает с 24.48 до 16
# >
# > основные изменения происходят после первого этапа очистки
# >
# * концентрация **свинца** в процессе обработки **растет**:
# >
# > среднее значение возрастает с 7.76 до 9.98
# >
# > максимальное значение возрастает с 13.61 до 17.03
# >
# > основные изменения также происходят после первого этапа очистки
# >
# * концентрация **золота** в процессе обработки **существенно возрастает**:
# >
# > среднее значение вырастает с 20.18 до 44.05
# >
# > максимальное значение вырастает с 28.82 до 52.75
# >
# > каждый этап обработки привносит одинаково значимый вклад в прирост концентрации
# >

# %% [markdown]
# ### Анализ распределения размеров гранул сырья на обучающей и тестовой выборках

# %%
# выводим список параметров, определяющих размер гранул на разных этапах очистки в обучающей выборке
data_train_feed_size = data_train.filter(regex = 'feed_size')
data_train_feed_size.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13795 entries, 0 to 14148
# Data columns (total 2 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   primary_cleaner.input.feed_size  13795 non-null  float64
#  1   rougher.input.feed_size          13795 non-null  float64
# dtypes: float64(2)
# memory usage: 323.3 KB

# %%
# выводим список параметров, определяющих размер гранул на разных этапах очистки в тестовой выборке
data_test_feed_size = data_test.filter(regex = 'feed_size')
data_test_feed_size.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 2 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   primary_cleaner.input.feed_size  5290 non-null   float64
#  1   rougher.input.feed_size          5290 non-null   float64
# dtypes: float64(2)
# memory usage: 82.8 KB

# %%
# строим гистограммы распределения данных
fig, ax = plt.subplots(2, 1)
fig.set_figheight(7)
fig.set_figwidth(15)
fig.suptitle('Распределение размера гранул на разных этапах в обучающей и тестовой выборках', y=0.95, size=16)

ax[0].hist(data_train['rougher.input.feed_size']\
, bins=100, alpha = 0.5, label = 'train_rougher.input.feed_size', density=True)
ax[0].hist(data_test['rougher.input.feed_size']\
, bins=100, alpha = 0.5, label = 'test_rougher.input.feed_size', density=True)
ax[0].legend()
ax[0].set_title('Размер гранул сырья на входе')
ax[0].grid()

ax[1].hist(data_train['primary_cleaner.input.feed_size']\
, bins=100, alpha = 0.5, label = 'train_primary_cleaner.input.feed_size', density=True)
ax[1].hist(data_test['primary_cleaner.input.feed_size']\
, bins=100, alpha = 0.5, label = 'primary_cleaner.output.concentrate_pb', density=True)
ax[1].legend()
ax[1].set_title('Размер гранул сырья после флотации')
ax[1].grid()

plt.show()

# %% [markdown]
# #### Выводы
# * распределения размеров гранул сырья на обучающей и тестовой выборках можно назвать эдентичными
# * на входе оба распределения имеют скошенность вправо с длинными хвостами
# * после флотации оба распределения стремятся к нормальному и одинаково центрированы
# * сильных отличий не вывлено; ожидается, что оценка модели будет правильной

# %% [markdown]
# ### Анализ суммарной концентрации всех веществ в сырье, черновом и финальном концентратах

# %%
# создаем копию датасета для изучения суммарных значений концентраций веществ
data_full_copy = data_full.copy()

# %%
# суммируем концентрацию всех веществ в сырье
data_full_copy['sum_concetrate_base']\
= data_full_copy['rougher.input.feed_ag']\
+ data_full_copy['rougher.input.feed_pb']\
+ data_full_copy['rougher.input.feed_sol']\
+ data_full_copy['rougher.input.feed_au']
display(data_full_copy['sum_concetrate_base'].describe())
# Out:
# count    18949.000000
# mean        57.328171
# std          7.175150
# min          0.040000
# 25%         53.536062
# 50%         57.600162
# 75%         61.969195
# max         76.978947
# Name: sum_concetrate_base, dtype: float64

# %%
# суммируем концентрацию всех веществ в черновом концентрате
data_full_copy['sum_concetrate_rougher']\
= data_full_copy['rougher.output.concentrate_ag']\
+ data_full_copy['rougher.output.concentrate_pb']\
+ data_full_copy['rougher.output.concentrate_sol']\
+ data_full_copy['rougher.output.concentrate_au']
display(data_full_copy['sum_concetrate_rougher'].describe())
# Out:
# count    18949.000000
# mean        69.571825
# std          7.790890
# min          0.040000
# 25%         66.321789
# 50%         70.324088
# 75%         74.446687
# max         88.140119
# Name: sum_concetrate_rougher, dtype: float64

# %%
# суммируем концентрацию всех веществ после первичной очистки
data_full_copy['sum_concetrate_primary']\
= data_full_copy['primary_cleaner.output.concentrate_ag']\
+ data_full_copy['primary_cleaner.output.concentrate_pb']\
+ data_full_copy['primary_cleaner.output.concentrate_sol']\
+ data_full_copy['primary_cleaner.output.concentrate_au']
display(data_full_copy['sum_concetrate_primary'].describe())
# Out:
# count    18949.000000
# mean        60.749922
# std          9.915693
# min          0.000000
# 25%         58.930717
# 50%         62.460419
# 75%         65.622916
# max         80.749343
# Name: sum_concetrate_primary, dtype: float64

# %%
# суммируем концентрацию всех веществ в финальном концентрате
data_full_copy['sum_concetrate_final']\
= data_full_copy['final.output.concentrate_ag']\
+ data_full_copy['final.output.concentrate_pb']\
+ data_full_copy['final.output.concentrate_sol']\
+ data_full_copy['final.output.concentrate_au']
display(data_full_copy['sum_concetrate_final'].describe())
# Out:
# count    18949.000000
# mean        69.000211
# std          5.573298
# min          0.040000
# 25%         67.943518
# 50%         69.600838
# 75%         71.373371
# max         80.210644
# Name: sum_concetrate_final, dtype: float64

# %%
# строим гистограмму распределения данных по всем этапам
plt.figure(figsize=(15, 5))

data_full_copy['sum_concetrate_base'].plot(kind = 'hist', color='orange', alpha = 0.5, label = 'sum_concetrate_base'\
                                         , bins = 100)
data_full_copy['sum_concetrate_rougher'].plot(kind = 'hist', color = 'blue', alpha = 0.5, label = 'sum_concetrate_rougher' \
                                         , bins = 100)
data_full_copy['sum_concetrate_primary'].plot(kind = 'hist', color='red', alpha = 0.5, label = 'sum_concetrate_primary'\
                                         , bins = 100)
data_full_copy['sum_concetrate_final'].plot(kind = 'hist', color='green', alpha = 0.5, label = 'sum_concetrate_final'\
                                         , bins = 100)
plt.title('Распределение данных о суммарной концентрации всех веществ на разных этапах')
plt.legend()
plt.show()

# %%
# проверяем объекты с нулевым значением суммы концентрации веществ после этапа первичной обработки
data_full_copy_sum_null = data_full_copy[data_full_copy['sum_concetrate_primary'] == 0]
display(data_full_copy_sum_null.shape)
# Out:
# (101, 91)

# %%
# проверяем параметры равные 0
data_full_copy_sum_null = data_full_copy_sum_null.drop('date', axis=1)
for column in data_full_copy_sum_null:
    if data_full_copy_sum_null[column].sum() == 0:
        print('null_is:',[column])
# Out:
# null_is: ['primary_cleaner.output.concentrate_ag']
# null_is: ['primary_cleaner.output.concentrate_pb']
# null_is: ['primary_cleaner.output.concentrate_sol']
# null_is: ['primary_cleaner.output.concentrate_au']
# null_is: ['sum_concetrate_primary']

# %% [markdown]
# #### Выводы
# * по результату прохождения этапов обработки суммарная концентрация веществ сокращает разброс данных
# * распределение уплотняется вокруг моды, мода растет
# * анализ нулевых значений показал очевидное наличие ошибки внесения данных по результатам первичного этапа обработки, влияющей на целевую переменную
# * **sum_concetrate_primary** - 101 объект равен нулю, т.к. пропущены значения слогаемых параметров:
# >
# > null_is: ['primary_cleaner.output.concentrate_ag']
# >
# > null_is: ['primary_cleaner.output.concentrate_pb']
# >
# > null_is: ['primary_cleaner.output.concentrate_sol']
# >
# >null_is: ['primary_cleaner.output.concentrate_au']
# >
# >null_is: ['sum_concetrate_primary']
# >
#
# все остальные параметры содержат ожидаемые значения
# * приянто решение удалить объекты из выборок

# %%
# отфильтровываем объекты с нулевыми значениями переменных из выборок
data_full = data_full[data_full['primary_cleaner.output.concentrate_ag'] > 0]
data_train = data_train[data_train['primary_cleaner.output.concentrate_ag'] > 0]

display(data_full.shape)
display(data_train.shape)
# Out:
# (18848, 87)
# (13725, 87)

# %% [markdown]
# ### Проверка распределения дат в обучающей и тестовой выборках

# %%
# выводим стат данные по датам в обучающей и тестовой выборках
train_date = data_train['date'].describe().to_frame().reset_index()
test_date = data_test['date'].describe().to_frame().reset_index()
train_test_date = train_date.join(test_date, how = 'left', rsuffix="_test", lsuffix="_train").drop('index_test', axis=1)
display(train_test_date)
# Out:
#   index_train           date_train            date_test
# 0       count                13725                 5290
# 1      unique                13725                 5290
# 2         top  2016-04-15 10:00:00  2016-11-20 05:59:59
# 3        freq                    1                    1
# 4       first  2016-01-15 00:00:00  2016-09-01 00:59:59
# 5        last  2018-08-18 10:59:59  2017-12-31 23:59:59

# %%
# выводим данные обучающей выборки позже 2016-01-09
display(data_train[data_train['date'] >= '2016-09-01'].shape)
# Out:
# (9103, 87)

# %%
# визуализируем временные ряды обучающей и тестовой выборок
plt.figure(figsize=(15, 5))
data_train['date'].plot(label='train')
data_test['date'].plot(label='test')
plt.legend()
plt.title('Параметр даты в обучающей и тестовой выборках');

# %% [markdown]
# #### Выводы
# * тестовая выборка подготовлена без учета хронологии дат
# * даты тестовой выборки совпадают с датами обучающей

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Формирование признаков и целевой перменной, стандартизация

# %%
# делим данные на признаки (features) и целевую переменную (target) для обучающей и тестовой выборок
columns = data_test.columns

features_train = data_train[columns] # формируем признаки, выбираем из trian только те параметры, которые есть в test
features_train = features_train.drop(['date'],axis=1) # удаляем параметр даты
target_train = data_train[['rougher.output.recovery','final.output.recovery']] # формируем вектор целевых признаков

data_test_target = data_test.join(data_full, how = 'left', rsuffix="_dummy") # создаем полный датасет со всеми признаками для тестовой выборки
data_test_target = data_test_target.dropna() # удаляем пропуски
features_test = data_test_target[columns] # формируем набор признаков тестовой выборки
features_test = features_test.drop(['date'],axis=1) # удаляем параметр даты
target_test = data_test_target[['rougher.output.recovery','final.output.recovery']] # формируем вектор целевых признаков

# %%
display(features_train.shape)
display(target_train.shape)
# Out:
# (13725, 52)
# (13725, 2)

# %%
display(features_test.shape)
display(target_test.shape)
# Out:
# (5157, 52)
# (5157, 2)

# %%
# стандартизируем данные
# обучаем StandartScaler на обучающей выборке

scaler = StandardScaler()
scaler.fit(features_train)

# преобразуем обучающий и валидационные наборы данных

features_train_st = scaler.transform(features_train)
features_test_st = scaler.transform(features_test)

# %% [markdown]
# ### Вывбор лучшей модели, кросс-валидация

# %%
# создаем функцию расчета метрики качества согласно условий проекта
def sMAPE(predict,target):
    
    predict_rougher = predict[:,0]
    target_rougher = target[:,0]
    
    predict_final = predict[:,1]
    target_final = target[:,1]
    
    sMAPE_rougher = np.sum(abs(target_rougher - predict_rougher) / ((abs(target_rougher) + abs(predict_rougher)) / 2))
    
    sMAPE_rougher = sMAPE_rougher / len(target_rougher) * 100
       
    sMAPE_final = np.sum(abs(target_final - predict_final) / ((abs(target_final) + abs(predict_final)) / 2))
    sMAPE_final = sMAPE_final / len(target_final) * 100
    
    sMAPE = 0.25 * sMAPE_rougher + 0.75 * sMAPE_final
    
    return sMAPE

# %%
# создаем скорер метрики качества
smape_scorer = make_scorer(sMAPE, greater_is_better = False)

# %% [markdown]
# #### LinearRegression

# %%
# кросс-валидация Линейная регрессия
lr = LinearRegression()
score = cross_val_score(lr, features_train_st, np.array(target_train), scoring = smape_scorer, cv=6).mean()
print('LinearRegression sMAPE:', abs(score))
# Out:
# LinearRegression sMAPE: 9.817139912061878

# %% [markdown]
# #### Lasso

# %%
# кросс-валидация Lasso
la = Lasso()
score = cross_val_score(la, features_train_st, np.array(target_train), scoring = smape_scorer, cv=6).mean()
print('LASSO sMAPE:', abs(score))
# Out:
# LASSO sMAPE: 8.799676620338262

# %% [markdown]
# #### DecisionTreeRegressor

# %%
# подбираем лучший гиперпараметр  max_depth с RandomizedSearchCV,
# выбираем метрику настройки sMAPE
max_depth = range(1, 50)
hyperparameters = dict(max_depth=max_depth)
dt = DecisionTreeRegressor(random_state = 0)

randomizedsearch = RandomizedSearchCV(dt, hyperparameters, random_state = 0 \
                                      , scoring= smape_scorer)

dt_best_model_random = randomizedsearch.fit(features_train, np.array(target_train))
print(dt_best_model_random.best_estimator_)
# Out:
# DecisionTreeRegressor(max_depth=8, random_state=0)

# %%
# кросс-валидация DecisionTreeRegressor
dt_best = DecisionTreeRegressor(random_state = 0, max_depth=8)

score = cross_val_score(dt_best, features_train_st, np.array(target_train), scoring = smape_scorer, cv=6).mean()
print('DecisionTreeRegressor sMAPE:', abs(score))
# Out:
# DecisionTreeRegressor sMAPE: 12.457260563472886

# %% [markdown]
# #### RandomForestRegressor

# %%
# подбираем лучшие гиперпараметры  n_estimators, max_depth, min_samples_leaf с RandomizedSearchCV,
# выбираем метрику настройки sMAPE
n_estimators = range(1, 100)
max_depth = range(1,50)
min_samples_leaf = range(1,13)

hyperparameters = dict( max_depth=max_depth, min_samples_leaf = min_samples_leaf, n_estimators = n_estimators)
rf = RandomForestRegressor(random_state = 0)

randomizedsearch = RandomizedSearchCV(rf, hyperparameters, random_state = 0, scoring = smape_scorer)

rf_best_model_random = randomizedsearch.fit(features_train, np.array(target_train))
print(rf_best_model_random.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=3, min_samples_leaf=4, n_estimators=60,
#                       random_state=0)

# %%
# кросс-валидация RandomForestRegressor
rf_best = RandomForestRegressor(random_state = 0, max_depth = 3, min_samples_leaf = 4, n_estimators = 60)

score = cross_val_score(rf_best, features_train, np.array(target_train), scoring = smape_scorer, cv=6).mean()
print('DecisionTreeRegressor sMAPE:', abs(score))
# Out:
# DecisionTreeRegressor sMAPE: 9.165328711909245

# %%
# делаем сводную таблицу результатов
model_best = pd.DataFrame(columns=(['model', 'random_state', 'cv_results', 'max_depth', 'min_samples_leaf', 'n_estimators']))
model_best.model = ['LinearRegression_lr', 'LASSO_la', 'DecisionTreeRegressor_dt', 'RandomForestRegressor_rf']
model_best.random_state = ['none', 'none', '0', '0']
model_best.cv_results = [9.82, 8.8, 12.46, 9.17]
model_best.max_depth = ['none', 'none', 8, 3]
model_best.min_samples_leaf = ['none', 'none', 'none', 3]
model_best.n_estimators = ['none', 'none', 'none', 60]

display(model_best.sort_values(by='cv_results'))
# Out:
#                       model random_state  cv_results max_depth  \
# 1                  LASSO_la         none        8.80      none
# 3  RandomForestRegressor_rf            0        9.17         3
# 0       LinearRegression_lr         none        9.82      none
# 2  DecisionTreeRegressor_dt            0       12.46         8
#
#   min_samples_leaf n_estimators
# 1             none         none
# 3                3           60
# 0             none         none
# 2             none         none

# %% [markdown]
# #### Выводы
# * для работы с моделями были подготовлены признаки и вектор целевых переменных
# * признаки были стандартизированы с помощью StandardScaler
# * для выбора лучшей модели были выбраны Линейная регрессия, Лассо, Дерево решений и Случайный лес
# * для Дерева решений и Случайного леса с помощью RandomizedSearchCV, настроенного на метрику sMAPE, были подобраны лучшие гиперпараметры
# * по результатам кросс-валидации с 6 фолдами лучший скор показала модель LASSO

# %% [markdown]
# ### Проверка лучшей модели на тестовой выборке

# %%
# проверяем лучшую модель на тестовой выборке
la = Lasso()
la.fit(features_train_st, target_train)
predict = la.predict(features_test_st)

smape = sMAPE(predict, np.array(target_test))
print('Симметричная средняя абсолютная ошибка лучшей модели LASSO:', smape)
# Out:
# Симметричная средняя абсолютная ошибка лучшей модели LASSO: 10.698614059516707

# %%
# производим проверку с константной моделью, настроенной на стратегию медианы
dummy_regr = DummyRegressor(strategy = "median")
dummy_regr.fit(features_train_st, target_train)
predict = dummy_regr.predict(features_test_st)

smape = sMAPE(predict, np.array(target_test))
print('Симметричная средняя абсолютная ошибка константной модели:', smape)
# Out:
# Симметричная средняя абсолютная ошибка константной модели: 9.821989482371976

# %% [markdown]
# #### Выводы
# * выбранная методом кросс-валидации лучшая модель LASSO показала на тестовой выборке результаты метрики SMAPE = 10.6986
# * проверка константной моделью DummyRegressor со страдегией медианы показала на тестовой выборке результаты метрики SMAPE = 9.8219
# * модель рекомендуется в качестве прототипа модели машинного обучения для компании, разрабатывающей решения для эффективной работы промышленных предприятий по восстановлению золота из золотоносной руды
